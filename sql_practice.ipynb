# %%
# from pyspark.sql.functions import concat, lit, regexp_extract, row_number
# from pyspark.sql.window import Window

# data = [('jagadish', 'gullipalli', 'vzm')]
# col = ['first', 'last', 'city']
# df = spark.createDataFrame(data=data, schema=col)

# # Display DataFrame with concatenated name
# display(df.withColumn('name', concat(df['first'], lit('_'), df['last'])))

# # Extract pattern from 'first' column
# df = df.withColumn('name', regexp_extract(df['first'], r'([a-z]+)', 1))

# # Add row_number using Window specification
# window = Window.orderBy('first')
# df = df.withColumn('demo', row_number().over(window))
# display(df)
# df.withcolumn('mail',when(col('email')=="",'none')).otherwise('personalmail')
# --------------------------------------------------------------------------
# # select name,nvl(salary,0) as new_salary from employee
# df.groupby('patinest').agg(count(*)).alias('pat_count')
# df.groupby(col('customerid')).agg(collect_list('name')).alias('descriptions')
# --------------------------------------------------------------------------------
# df.groupby('productid').agg(collect_set('product_id')).alias('unique_product')
# large_df.hint('broadcast').join('cus_df,'cust_id',how='inner)
# select * from  information.schema where table='dim_employee'
# spark.read.csv("csv_filepath")
# df.withcolumn('filename',input_file_name())
# df.columns\.dtype
# spar.readstram.format('cloudfiles').options('cloudfiles.format','csv').load('file_path')
# -----------------------------------------------------------------------------------------
# lag(column,offset,default)
# lag('salary',2,0) over(partition by dept order by salary)
# window_spec=window.partitionby('storedid').orderby('mont')
# df=df.withcolumn('prev_sales',lag('sales').over(window_spec))
# df=df.withcolumn('growth',col('sales')-col(prev_sales))
# display(df)
# -----------------------------------------------------------------
# df.withpartitibvyrange(10,'order_id').sortwithpartition('orderid')
# df.withcolumn('order',explode(col('orders'))).display()
# df.withcolumn('customerid',explode('orders'))
# df.select('customerid',col('orders.id'),col('orders.amount'))
# -------------------------------------------------------------
# from spark.sql.functions import explode_outer
# df.withcolumn('prodcuts',explode_outer(col('prodcuts'))).display()
# df.select(posexplode('marks'))
# playlist_df=df.select('books_id',posexplode('books')).alias("id",'demo')
# df.select('student_id',inline('marks'))
# -----------------------------------------------------------------------------
# df.select(array_zip('product','price')).alias('result')
# df.withcolumn('key_skill',array_contains('skills','pyspark'))
# df.select('pro_id',flatten('order_list'))
# df.select('customer',size('orders')).alias('order_count')
# df.groupby(;student_id).agg(count('*')).alias('student_count').filter('student_count>2').display()
# df.select(coalsce(size('products'),lit('0'))).alias('count_product')
# df.select('order_id',map_keys('marks')).alias('marks_values')
# df.withcolumn('demo',concat('_','first','last'))
# --------------------------------------------------------------------------------------------------------
# df.select(substring('name',1,4))
# df.select('city',explode(split('address','\\|',1)))
# from pyspark.sql import SparkSession

# spark = SparkSession.builder.getOrCreate()

# data = [
#     (1, "John123"),
#     (2, "Mike@abc.com"),
#     (3, "$2500"),
#     (4, "987-654-3210")
# ]

# df = spark.createDataFrame(data, ["id","value"])

# df.show(truncate=False)
# df.withcolumn('value',regexp_replace('values','[^a-zA-z0-9]','')).regexp_replace('num','\\s+','')
# df.withcolumn('han_nul',egexp_replace(coalsce('id',lit(none)),'\\s+',"")
# from pysaprk.sql.function import regexp_extract as rex
# df.withcolumn('number',regexp_extract('text',()))
df.select('bp',rex('melop','@[.+]'),1).rex('day','\\d{2}',2)\.
# https://www.google.com/search
rex('url','https+:[^/]+')\.translate('code','abc','xyz')\.translate('number','_',"")
data=[('kamal',),("",),(none,)]
spark.CreateDataframe(data,['stamp'])
df.withcolumn('len',leangth(trim("stamp"))\.instr('text','@')\.lpad('name',10,x)\.rpad('name',10,x)

df.select(current_date().alias('date'),current_timestamp().alias('timestamp))\.withColumn('date',to_date('ingest_date','MM-dd-yyyy'))\.datediff(current_date(),to_date('lastdate'))\.date('delivery_date',10)\.dateformat('order_date','yyyy-MM-dd')\.dateadd('order_date',10)
-------------------------------------------------------------------------------------------------------------------------------
from pyspark.sql.function import structType,Structfiled
schema=structType((structfiles('id','int'),structfiles('name','string)))
df.withColumn('demo',from_json('value',schema))\.seelct('demo.id','demo.name')\.withcolumn('employee',struct('id','name','salary'))\.withcolumn(from_col',to_json(employee))\.df1.excepall(df2)\.df3.intersect(df4)\.fillna('unknown',subset=['city','name])\.

# %%
#  t=(21,23,(10,32,11))
# # print(dir(t))
# print(sum(t))
# d={(100,'jam'):'data'}
# # for i,j in d.items():
# print(d.values())
# tp=(101,{'name':'mani','salary':10000})
# tp[1]['salary']=21000
# print(tp)
# def inde_trck(key,target):
#     return [i for i,val in enumerate(key) if val==target]
# print(inde_trck([30,20,30,40,30],30))
# --------------------------------------
# def unique_num(items):
#     return len(items)==len(set(items))
# data1=[10,20,40]
# print(unique_num(data1))
# def rep_num(tp):
#     dtas=list(tp)
#     dtas[0],[-1]=dtas[0],dtas[-1]
#     return tuple(dtas)
# tp=(10,20,30)
# print(rep_num(tp))
# def flattern_tup(tps):
#     return [item for sub in tps for item in sub]
# new_nest=((10,20),(30,40),(50,60))
# print(flattern_tup(new_nest))
# def new_flat(ts):
#     res=[]
#     for sub in ts:
#         for items in sub:
#             res.append(items)
#     return res
# new_nest=((10,20),(30,40),(50,60))
# print(new_flat((new_nest)))
# my_tuple = (1, "apple", 3.5, "banana", True, "cherry", None, 42)
# def is_str(stp):
#     return [item for item in stp if isinstance(item,str)]
# print(is_str(my_tuple))
#  tp1=('a','b','c')
#  tp2=('c','b','a')
# # res=set(tp1)|set(tp2)
# # print(res)
# for i in tp1:
# def is_anagram(s1,s2):
#     return sorted(s1)==sorted(s2)
# print(is_anagram('abc','cba'))
# my_ts=(1,2,3,4,5)
# def freq_num(fsp):
#     freq={}
#     for item in fsp:
#         freq[item]=freq.get(item,0)+1
#     return freq
# print(freq_num(my_ts))
